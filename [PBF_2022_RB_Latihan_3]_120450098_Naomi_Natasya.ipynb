# %% [markdown]
# <a href="https://colab.research.google.com/github/naomintsy/Jurnal-Pemrograman-Basis-Fungsi/blob/main/%5BPBF_2022_RB_Latihan_2%5D_120450098_Naomi_Natasya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Naomi Natasya
#
# NIM : 120450098
#
# RB

# %% [markdown]
# Bandingkan dan analisis terhadap fungsi transmogrify dan no_mogrify

# %% [markdown]
# **PERBANDINGAN**
#
# Transmogrify
# 1. Transmogrify dapat mengubah angka sesuai dengan tempat angka yang dinyatakan dalam fungsi
# 2. Objek fungsi kemudian disimpan dalam daftar yang dideklarasikan sebelumnya dan keluar ketika x dideklarasikan.
#
# No Mogrify
# 1. Hanya bisa menampilkan angka yg telah dideklarasikan pada fungsi
# 2. Saat fungsi dipanggil, hasilnya ditampilkan sesuai dengan objek yang telah dideklarasikan

# %%
def transmogrify(x):
 x[0] = 999
 return x
## Main Program
x = [1,2,3]
print (x)
print (transmogrify(x))
print (x)
# Out:
# [1, 2, 3]
# [999, 2, 3]
# [999, 2, 3]

# %%
def no_mogrify(x):
 x = [4,5,6]
 return x
## Main Program 
x = [1,2,3]
print (x)
print (no_mogrify(x))
print (x)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [1, 2, 3]

# %% [markdown]
# **ANALISIS**
#
# Transmogrify adalah manipulator gambar berbasis Python. Pada gambar di atas, Anda dapat melihat bahwa ada fungsi yang disebut transmogrify, yang memiliki variabel x [0] = 999 dan x = [1,2,3].
# Ketika memanggil x pertama, [1, 2, 3] sesuai dengan variabel yang dipanggil. kedua memanggil x dari fungsi transmogrify (x) dan menampilkan [999,2,3]. Ini adalah karena indeks Python dimulai dari 0. Kemudian x [0] dalam fungsi memperbarui x ketika: Saat dipanggil, hasil keluarannya adalah [999,2,3], dan panggilan ketiga dari menghasilkan [999,2,3]. Ini bukan [1,2,3] karena program berjalan
# dengan Python. untuk melihat hasil x terbaru. Ini adalah salah satu contoh operasi bilangan
#
#
# Pada function kedua yaitu no_mogrify terdapat variable x = [1,2,3] dan x = [4,5,6] pada saat pemanggilan pertama x yang muncul adalah x yang diluar dari function no_mogrify yaitu [1,2,3] dan
# pemanggilan kedua yaitu pemanggilan function no_mogrify(x) maka yang mungcul adalah angka yang ada dalam function tersebut yaitu [4,5,6], kemudian pemanggilan yang ketiga yang muncul
# adalah [1,2,3] kenapa tidak sama seperti yang transmogrify karena variable x pada function no_mogrify tidak ada yang dimanipulasi sehingga hasil yang diminta pun tidak ada yang diperbarui maka
# Ketika pemanggilan x ketiga yang muncul tetap [1,2,3]
